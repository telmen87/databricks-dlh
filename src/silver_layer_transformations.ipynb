# %%
import logging 
from log_utils import setup_logging

# %%
logger = logging.getLogger(__name__)
setup_logging()

# %%
# insert into bronze layer tables
raw_layer_tables = [
    
]

# %%
for table in raw_layer_tables:
    (
        spark.table()
    )
